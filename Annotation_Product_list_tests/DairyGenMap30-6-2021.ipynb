# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
# %cd C:\MyCode\Dor-Alon\GenerateMapping28-6-2021
# %pwd
# %ls
# Out:
# C:\MyCode\Dor-Alon\GenerateMapping28-6-2021
#  Volume in drive C is OS
#  Volume Serial Number is F02F-ED47
#
#  Directory of C:\MyCode\Dor-Alon\GenerateMapping28-6-2021
#
# 06/29/2021  03:17 PM    <DIR>          .
# 06/29/2021  03:17 PM    <DIR>          ..
# 06/27/2021  11:18 PM            74,520 doralon_mixed-product-list-v-01.xlsx
# 06/28/2021  10:18 PM           122,816 doralon_mixed-product-list-v-02.xlsx
# 06/14/2021  09:30 AM           617,912 DorAlonProduct ListFull.xlsx
# 06/29/2021  03:16 PM            44,805 NutsandSeeds29-6-2021.xlsx
# 06/29/2021  09:19 AM           122,816 ProductList28-6-2021.xlsx
# 06/29/2021  03:35 AM            45,271 SaltySnacks29-6-2021.xlsx
# 06/29/2021  01:26 AM            53,335 Waffles_and_cookies-28-6-2021.xlsx
# 06/29/2021  02:51 AM            45,447 wafflesandcookiesoldproductlist.xlsx
#                8 File(s)      1,126,922 bytes
#                2 Dir(s)  672,722,280,448 bytes free

# %%
product_list_orig = pd. read_excel('DorAlonProduct ListFull.xlsx')
print(product_list_orig.columns)
# Out:
# Index(['SKU', 'Class-Name', 'Width', 'Height', 'Depth', 'Shelf-Count',
#        'Image-URL', 'Hebrew-Brand', 'Brand', 'Model-Name',
#        'Hebrew-Description', 'English-Description', 'Annotations-Name',
#        'in Planogram?', 'Category', 'Sub-Category', 'Power-SKU', 'Size',
#        'draft', 'draft2', 'brand', 'Shelf'],
#       dtype='object')

# %%
partial_orig = product_list_orig[['SKU', 'Class-Name', 'Shelf' ,'Annotations-Name']]
dairy = partial_orig.loc[partial_orig['Shelf'] == 'Dairy']
print(dairy[['SKU' ,'Annotations-Name']])
print(len(dairy.index))
# Out:
#                SKU                   Annotations-Name
# 4    7290014760141    AlmondsDrinkTnuva_7290014760141
# 5          4125578                Alternative_4125578
# 6    7290110325619          Alternative_7290110325619
# 7          4125585                Alternative_4125585
# 8    7290014763289  AlternativeDrink250_7290014763289
# ..             ...                                ...
# 729  7290105368959  Yotvata-SmallBottle_7290105368959
# 730  7290011438142  Yotvata-SmallBottle_7290011438142
# 731  7290112341112  Yotvata-SmallBottle_7290112341112
# 732        3029433        Yotvata-SmallBottle_3029433
# 733  7290112342621  Yotvata-SmallBottle_7290112342621
#
# [100 rows x 2 columns]
# 100

# %%
product_list_new = pd. read_excel('ProductList28-6-2021.xlsx')
print(product_list_new.columns)
# Out:
# Index(['SKU', 'Class-Name', 'Width', 'Height', 'Depth', 'Shelf-Count',
#        'Image-URL', 'Hebrew-Brand', 'Brand', 'Hebrew-Description',
#        'English-Description', 'Category', 'Sub-Category', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15'],
#       dtype='object')

# %%
new_partial = product_list_new[['SKU','Class-Name','Brand']]
#print(new_partial)
#new_partial['flag'] = False
#df_0 = pd.DataFrame(0, index=range(height), columns=range(width))
#df.insert(2, "Age", [21, 23, 24, 21], True)
new_partial.insert(0,'flag', np.zeros(len(new_partial)))
new_partial['flag'] = False
new_partial.insert(1,'Annotations', np.zeros(len(new_partial)))
new_partial['Annotations-Name'] = 'zero_string'
#new_partial.loc['flag'] = False
print(new_partial)
# Out:
#       flag  Annotations            SKU  \
# 0    False          0.0   856591000062
# 1    False          0.0  7290002132011
# 2    False          0.0   856591000109
# 3    False          0.0  7290002771111
# 4    False          0.0  7290014760141
# ..     ...          ...            ...
# 757  False          0.0  7290110328382
# 758  False          0.0  7290110321796
# 759  False          0.0  7290014761070
# 760  False          0.0  7290014761414
# 761  False          0.0  7290008693134
#
#                                             Class-Name              Brand  \
# 0    Abadi_Abadi cookies Oriental taste with salt 400g              Abadi
# 1                    Abadi_Eastern Abadi cookies, 400g              Abadi
# 2      Abadi_Ebadi ottomans extra crispy biscuits 400g              Abadi
# 3        El-Nachle_Al Nakhla coffee with cardamom 250g          El Nachle
# 4         AlmondsDrinkTnuva_Fresh almond drink 1 liter  AlmondsDrinkTnuva
# ...

# %%
#column_names = ['SKU', 'Class-Name', 'Brand']
#result= pd.DataFrame(columns = column_names)
for index,row in dairy.iterrows():
    #print(row["SKU"])
    curr_sku = row["SKU"]
    curr_annotation = row['Annotations-Name']
    new_partial.loc[new_partial['SKU'] ==  curr_sku, 'flag'] = True
    new_partial.loc[new_partial['SKU'] ==  curr_sku, 'Annotations'] = curr_annotation
    #new_partial['flag'] = np.where(new_partial['SKU'] ==  curr_sku, True, False)
    #print(new_partial)
print(new_partial.loc[new_partial['flag'] == True])
#print(result)
#result = 
new_partial.to_excel("result.xlsx")
# Out:
# C:\Users\orlya\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\orlya\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\orlya\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# ...
